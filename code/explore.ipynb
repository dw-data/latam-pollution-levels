# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Cities_PM25_DailyMeans.csv")

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.set_index('date')

# %%
df['mean'] = df['mean'] * 1e9

# %% [markdown]
# # mask = df.loc["2024-08-12":"2024-09-09"]['UC_NM_MN'] =='Porto Velho'
# df.loc["2024-08-12":"2024-09-09"][mask].plot(y='mean', kind='bar')

# %%
df
# Out:
#                                  system:index CTR_MN_ISO CTR_MN_NM  ID_HDC_G0
# date
# 2024-08-10 00:00:00    0_00000000000000000292        BRA    Brazil      682.0  \
# 2024-08-10 00:00:00    0_000000000000000002d4        BRA    Brazil      751.0
# 2024-08-10 00:00:00    0_0000000000000000031d        BRA    Brazil      826.0
# 2024-08-10 00:00:00    0_0000000000000000037e        BRA    Brazil      926.0
# 2024-08-10 00:00:00    0_0000000000000000038b        BRA    Brazil      939.0
# ...                                       ...        ...       ...        ...
# 2024-09-10 21:00:00  255_00000000000000000584        BRA    Brazil     1445.0
# 2024-09-10 21:00:00  255_00000000000000000585        BRA    Brazil     1446.0
# 2024-09-10 21:00:00  255_00000000000000000586        BRA    Brazil     1447.0
# 2024-09-10 21:00:00  255_00000000000000000587        BRA    Brazil     1448.0
# 2024-09-10 21:00:00  255_00000000000000000588        BRA    Brazil     1449.0
#
# ...
